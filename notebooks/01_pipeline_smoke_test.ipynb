# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[0]
sys.path.append(str(PROJECT_ROOT))

# %%
from src.pipeline import run_pipeline
from src.db import get_engine

# %%
engine = get_engine()

# run_pipeline("TLKM.JK", engine)

# %%
# run_pipeline(["TLKM.JK", "BBCA.JK"], engine)

# %%
run_pipeline("TLKM.JK", engine)
run_pipeline("BBCA.JK", engine)
run_pipeline("AAPL", engine)
# Out:
# 2026-01-03 18:23:55,335 | INFO     | yfinance_pipeline | Starting pipeline for: TLKM.JK
# 2026-01-03 18:23:55,342 | INFO     | yfinance_pipeline | No existing data found — Full historical load
# 2026-01-03 18:23:55,344 | INFO     | yfinance_pipeline | Fetching data for TLKM.JK
# [*********************100%***********************]  1 of 1 completed
# 2026-01-03 18:23:56,223 | INFO     | yfinance_pipeline | Inserting 5242 rows into daily_prices
# date      datetime64[ns]
# close            float64
# high             float64
# low              float64
# open             float64
# volume             int64
# ticker            object
# dtype: object
#          close        rsi
# 0   341.332367        NaN
# 1   341.332367        NaN
# 2   343.401031        NaN
# 3   347.538361        NaN
# 4   359.950470        NaN
# 5   364.087860        NaN
# 6   355.813080        NaN
# 7   353.744507        NaN
# 8   353.744507        NaN
# 9   359.950470        NaN
# 10  353.744507        NaN
# 11  359.950470        NaN
# 12  355.813080        NaN
# 13  355.813080  62.962975
# 14  353.744507  60.714400
# 15  364.087860  66.666771
# 16  357.881805  60.000059
# 17  351.675781  52.777831
# 18  359.950470  50.000000
# 19  355.813080  44.117570
# 2026-01-03 18:23:58,964 | INFO     | yfinance_pipeline | Pipeline completed successfully for: TLKM.JK
# 2026-01-03 18:23:58,964 | INFO     | yfinance_pipeline | Starting pipeline for: BBCA.JK
# 2026-01-03 18:23:58,964 | INFO     | yfinance_pipeline | No existing data found — Full historical load
# 2026-01-03 18:23:58,964 | INFO     | yfinance_pipeline | Fetching data for BBCA.JK
# [*********************100%***********************]  1 of 1 completed
# 2026-01-03 18:23:59,515 | INFO     | yfinance_pipeline | Inserting 5323 rows into daily_prices
# date      datetime64[ns]
# close            float64
# high             float64
# low              float64
# open             float64
# volume             int64
# ticker            object
# dtype: object
#          close        rsi
# 0    99.041382        NaN
# 1   100.436325        NaN
# 2   100.436325        NaN
# 3   100.436325        NaN
# 4    99.041382        NaN
# 5   101.831245        NaN
# 6   100.436325        NaN
# 7    99.041382        NaN
# 8    99.041382        NaN
# 9    99.041382        NaN
# 10   99.041382        NaN
# 11  100.436325        NaN
# 12  100.436325        NaN
# 13  101.831245  62.499974
# 14  101.831245  62.499974
# 15  103.226212  62.500051
# 16  104.621170  66.666768
# 17  112.546989  79.566650
# 18  114.132156  86.503165
# 19  114.132156  84.397293
# 2026-01-03 18:24:02,539 | INFO     | yfinance_pipeline | Pipeline completed successfully for: BBCA.JK
# 2026-01-03 18:24:02,542 | INFO     | yfinance_pipeline | Starting pipeline for: AAPL
# 2026-01-03 18:24:02,548 | INFO     | yfinance_pipeline | No existing data found — Full historical load
# 2026-01-03 18:24:02,550 | INFO     | yfinance_pipeline | Fetching data for AAPL
# [*********************100%***********************]  1 of 1 completed
# 2026-01-03 18:24:03,389 | INFO     | yfinance_pipeline | Inserting 6540 rows into daily_prices
# date      datetime64[ns]
# close            float64
# high             float64
# low              float64
# open             float64
# volume             int64
# ticker            object
# dtype: object
#        close        rsi
# 0   0.839281        NaN
# 1   0.768521        NaN
# 2   0.779767        NaN
# 3   0.712287        NaN
# 4   0.746027        NaN
# 5   0.732906        NaN
# 6   0.695417        NaN
# 7   0.653711        NaN
# 8   0.725408        NaN
# 9   0.753056        NaN
# 10  0.779298        NaN
# 11  0.798980        NaN
# 12  0.850996        NaN
# 13  0.834595  49.521100
# 14  0.796637  45.955557
# 15  0.841624  57.289702
# 16  0.826160  54.587633
# 17  0.824754  62.793222
# 18  0.761960  51.700007
# 19  0.777893  54.771339
# 2026-01-03 18:24:06,523 | INFO     | yfinance_pipeline | Pipeline completed successfully for: AAPL
