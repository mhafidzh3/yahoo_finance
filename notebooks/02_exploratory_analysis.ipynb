# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[0]
sys.path.append(str(PROJECT_ROOT))

# %%
import pandas as pd
from src.db import get_engine

# %%
from src.transform import (
    add_moving_averages,
    add_daily_returns,
    add_rsi
)

# %%
engine = get_engine(
    user="postgres",
    password="admin",
    host="localhost",
    port=5432,
    db="stock_data"
)

# %%
df = pd.read_sql("""
    SELECT *
    FROM daily_prices
    WHERE ticker = 'TLKM.JK'
    ORDER BY date
""", engine)

# %%
df = df.sort_values("date")

# %%
display(df.head(), df.tail())
# Out:
#    id   ticker        date      open      high       low     close     volume  \
# 0   1  TLKM.JK  2004-09-28  345.4697  345.4697  341.3324  341.3324   90095000
# 1   2  TLKM.JK  2004-09-29  341.3324  341.3324  335.1263  341.3324   29370000
# 2   3  TLKM.JK  2004-09-30  341.3325  343.4012  341.3325  343.4012   42927500
# 3   4  TLKM.JK  2004-10-01  343.4010  349.6070  341.3323  347.5384  108387500
# 4   5  TLKM.JK  2004-10-04  349.6071  364.0879  349.6071  359.9505  424210000
#
#                   created_at
# 0 2026-01-01 15:07:38.819122
# 1 2026-01-01 15:07:38.819122
# 2 2026-01-01 15:07:38.819122
# 3 2026-01-01 15:07:38.819122
# 4 2026-01-01 15:07:38.819122
#         id   ticker        date    open    high     low   close     volume  \
# 5236  5237  TLKM.JK  2025-12-22  3440.0  3490.0  3420.0  3470.0  113720300
# 5237  5238  TLKM.JK  2025-12-23  3470.0  3470.0  3420.0  3470.0   39083700
# 5238  5239  TLKM.JK  2025-12-24  3480.0  3500.0  3440.0  3460.0   30919800
# 5239  5240  TLKM.JK  2025-12-29  3480.0  3530.0  3460.0  3490.0   53079900
# 5240  5241  TLKM.JK  2025-12-30  3490.0  3510.0  3480.0  3480.0   48019100
#
#                      created_at
# 5236 2026-01-01 15:07:38.819122
# 5237 2026-01-01 15:07:38.819122
# 5238 2026-01-01 15:07:38.819122
# 5239 2026-01-01 15:07:38.819122
# 5240 2026-01-01 15:07:38.819122

# %%
df = add_moving_averages(df, price_col="close")
df = add_daily_returns(df, price_col="close")
df = add_rsi(df, price_col="close")

# %%
display(df.head(), df.tail())
# Out:
#    id   ticker        date      open      high       low     close     volume  \
# 0   1  TLKM.JK  2004-09-28  345.4697  345.4697  341.3324  341.3324   90095000
# 1   2  TLKM.JK  2004-09-29  341.3324  341.3324  335.1263  341.3324   29370000
# 2   3  TLKM.JK  2004-09-30  341.3325  343.4012  341.3325  343.4012   42927500
# 3   4  TLKM.JK  2004-10-01  343.4010  349.6070  341.3323  347.5384  108387500
# 4   5  TLKM.JK  2004-10-04  349.6071  364.0879  349.6071  359.9505  424210000
#
#                   created_at       ma_5  ma_20  ma_50  daily_return  rsi
# 0 2026-01-01 15:07:38.819122        NaN    NaN    NaN           NaN  NaN
# 1 2026-01-01 15:07:38.819122        NaN    NaN    NaN      0.000000  NaN
# 2 2026-01-01 15:07:38.819122        NaN    NaN    NaN      0.006061  NaN
# 3 2026-01-01 15:07:38.819122        NaN    NaN    NaN      0.012048  NaN
# 4 2026-01-01 15:07:38.819122  346.71098    NaN    NaN      0.035714  NaN
#         id   ticker        date    open    high     low   close     volume  \
# 5236  5237  TLKM.JK  2025-12-22  3440.0  3490.0  3420.0  3470.0  113720300
# 5237  5238  TLKM.JK  2025-12-23  3470.0  3470.0  3420.0  3470.0   39083700
# 5238  5239  TLKM.JK  2025-12-24  3480.0  3500.0  3440.0  3460.0   30919800
# 5239  5240  TLKM.JK  2025-12-29  3480.0  3530.0  3460.0  3490.0   53079900
# 5240  5241  TLKM.JK  2025-12-30  3490.0  3510.0  3480.0  3480.0   48019100
#
#                      created_at    ma_5   ma_20   ma_50  daily_return  \
# 5236 2026-01-01 15:07:38.819122  3472.0  3568.0  3447.2      0.017595
# 5237 2026-01-01 15:07:38.819122  3462.0  3559.0  3457.4      0.000000
# 5238 2026-01-01 15:07:38.819122  3454.0  3546.0  3465.0     -0.002882
# 5239 2026-01-01 15:07:38.819122  3460.0  3542.0  3475.8      0.008671
# 5240 2026-01-01 15:07:38.819122  3474.0  3540.5  3487.8     -0.002865
#
#             rsi
# 5236  43.835616
# 5237  42.253521
# 5238  37.313433
# 5239  33.333333
# 5240  36.842105

# %%
df[["ma_5", "ma_20", "ma_50", "daily_return", "rsi"]].isna().sum()
# Out:
# ma_5             4
# ma_20           19
# ma_50           49
# daily_return     1
# rsi             13
# dtype: int64
